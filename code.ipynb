# %% [markdown]
# download VGG16 pre-trained weights from here https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5

# %% [markdown]
# find the rest of the code here https://drive.google.com/file/d/1cdLIWu9omNws4iIpO0gDuzGnndamMhDj/view?usp=sharing

# %% [markdown]
# # 1. Visualize Problem

# %%
from visualize_problem_statement import visualize_data

# %matplotlib inline

# %%
visualize_data(file_num=10, data_type='Train')

# %% [markdown]
# # 2. Train

# %%
from train import train_all
# Out:
# Using TensorFlow backend.

# %%
train_all()
# Out:
# (1280, 100)
# 2.3.1
# Parsing annotation files
# idx=660
# Spend 0.41 mins to load the data
# Training images per class:
# {'bg': 0, 'signature': 660}
# Num classes (including bg) = 2
# {'signature': 0, 'bg': 1}
# Config has been written to model_vgg_config.pickle, and can be loaded when testing to ensure correct results
# Num train samples (images) 660
# Original image: height=1000 width=1000
# Resized image:  height=300 width=300 C.im_size=300
# Feature map size: height=18 width=18 C.rpn_stride=16
# (1, 300, 300, 3)
# 2 includes 'y_rpn_cls' and 'y_rpn_regr'
# Shape of y_rpn_cls (1, 18, 18, 18)
# Shape of y_rpn_regr (1, 18, 18, 72)
# {'filepath': '568.tif', 'width': 1000, 'height': 1000, 'bboxes': [{'class': 'signature', 'x1': 507, 'x2': 895, 'y1': 825, 'y2': 964}]}
# Number of positive anchors for this image: 1
# (array([14, 16, 16], dtype=int64), array([11, 13, 13], dtype=int64), array([ 1,  2, 11], dtype=int64))
# ...

# %% [markdown]
# # 3. Test

# %%
from test import *

# %%
test1()

# %%
from test import test2
# Out:
# Using TensorFlow backend.
# Loading weights from model_frcnn_vgg.hdf5
# {0: 'signature', 1: 'bg'}
# ['752.tif', '763.tif', '728.tif', '746.tif', '767.tif', '785.tif', '773.tif', '730.tif', '710.tif', '700.tif', '700.tif', '695.tif']
# 752.tif
# Elapsed time = 6.6087870597839355
# [('signature', 87.34735250473022), ('signature', 86.5216076374054)]
# 763.tif
# Elapsed time = 5.71083402633667
# [('signature', 96.52215242385864)]
# 728.tif
# Elapsed time = 5.9918599128723145
# [('signature', 99.43312406539917)]
# 746.tif
# Elapsed time = 5.52741551399231
# [('signature', 97.56518602371216), ('signature', 95.8489716053009), ('signature', 88.02398443222046), ('signature', 87.34070062637329), ('signature', 86.65689826011658)]
# 767.tif
# Elapsed time = 5.079391002655029
# []
# 785.tif
# Elapsed time = 6.038405656814575
# [('signature', 97.17939496040344), ('signature', 85.85596084594727)]
# 773.tif
# Elapsed time = 5.1959309577941895
# ...
