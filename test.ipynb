# %%
from test import test2
# Out:
# Using TensorFlow backend.
# Loading weights from model_frcnn_vgg.hdf5
# {0: 'signature', 1: 'bg'}
# 752.tif
# Elapsed time = 6.79986834526062
# [('signature', 87.34735250473022), ('signature', 86.5216076374054)]
# 763.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-18ceb6ca858f> in <module>
# ----> 1 from test import test2
#
# e:\ITI_AI\Phase 2\22. CV\t4\FasterRCNN\test.py in <module>
#     262         plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#     263         plt.show()
# --> 264
#     265 test2()
#
# e:\ITI_AI\Phase 2\22. CV\t4\FasterRCNN\test.py in test2()
#     198             if ROIs.shape[1] == 0:
#     199                 break
# --> 200
#     201             [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])
#     202
#
# ...

# %%
test2
